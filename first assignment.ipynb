# %% [markdown]
# # Excercise 1

# %%
#Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data
#Step 2. Download the dataset to your computer and unzip it.

# %% [markdown]
# # Step 3. Use the tsv file and assign it to a dataframe called food

# %%
import pandas as pd
import numpy as np

# %%
food=pd.read_csv(r"E:\class data science\datasets\datasets\en.openfoodfacts.org.products.tsv",sep="\t")
# Out:
# C:\Users\Shreya Chandoba\AppData\Local\Temp\ipykernel_1852\864682962.py:1: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   food=pd.read_csv(r"E:\class data science\datasets\datasets\en.openfoodfacts.org.products.tsv",sep="\t")

# %% [markdown]
# # Step 4. See the first 5 entries

# %%
food.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %% [markdown]
# # Step 5. What is the number of observations in the dataset?

# %%
len(food)
# Out:
# 356027

# %% [markdown]
# # Step 6. What is the number of columns in the dataset?

# %%
len(food.columns)
# Out:
# 163

# %%
food.shape
# Out:
# (356027, 163)

# %%
#by shape function we can find total number of rows and number of columns

# %% [markdown]
# # Step 7. Print the name of all the columns.

# %%
print(food.columns)
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %%
list(food.columns)
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'created_datetime',
#  'last_modified_t',
#  'last_modified_datetime',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_en',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'labels',
#  'labels_tags',
#  'labels_en',
#  'emb_codes',
#  'emb_codes_tags',
#  'first_packaging_code_geo',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'countries',
#  'countries_tags',
#  'countries_en',
#  'ingredients_text',
#  'allergens',
#  'allergens_en',
#  'traces',
#  'traces_tags',
#  'traces_en',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'additives_en',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
# ...

# %%
for i in food.columns:
    print(i)
# Out:
# code
# url
# creator
# created_t
# created_datetime
# last_modified_t
# last_modified_datetime
# product_name
# generic_name
# quantity
# packaging
# packaging_tags
# brands
# brands_tags
# categories
# categories_tags
# categories_en
# origins
# origins_tags
# manufacturing_places
# manufacturing_places_tags
# labels
# labels_tags
# labels_en
# emb_codes
# emb_codes_tags
# first_packaging_code_geo
# cities
# cities_tags
# purchase_places
# stores
# countries
# countries_tags
# countries_en
# ingredients_text
# allergens
# allergens_en
# traces
# traces_tags
# traces_en
# serving_size
# no_nutriments
# additives_n
# additives
# additives_tags
# additives_en
# ingredients_from_palm_oil_n
# ingredients_from_palm_oil
# ingredients_from_palm_oil_tags
# ingredients_that_may_be_from_palm_oil_n
# ingredients_that_may_be_from_palm_oil
# ingredients_that_may_be_from_palm_oil_tags
# nutrition_grade_uk
# nutrition_grade_fr
# pnns_groups_1
# pnns_groups_2
# states
# states_tags
# states_en
# ...

# %%
 

 

 
Step 9. What is the type of the observations of the 105th column?

# %% [markdown]
# # Step 8. What is the name of 105th column?

# %%
food.columns[104]
# Out:
# '-glucose_100g'

# %%
for i in range(len(data.columns)):
    if i==104:
        print(data.columns[i])
# Out:
# -glucose_100g

# %%
Step 11. What is the product name of the 19th observation?

# %% [markdown]
# # Step 9. What is the type of the observations of the 105th column?

# %%
print(type(food.columns[104]))
# Out:
# <class 'str'>

# %% [markdown]
# # Step 10. How is the dataset indexed?

# %%
#Indexing can be done by using loc and iloc fuction

# %%
food.iloc[0:5,2:9]
# Out:
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3      1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4      1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#   generic_name
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
food.loc[:,["creator","generic_name"]]
# Out:
#                            creator                     generic_name
# 0       openfoodfacts-contributors                              NaN
# 1                  usda-ndb-import                              NaN
# 2                  usda-ndb-import                              NaN
# 3                  usda-ndb-import                              NaN
# 4                  usda-ndb-import                              NaN
# ...                            ...                              ...
# 356022             usda-ndb-import                              NaN
# 356023                      tomato  Leba pickle flavor potato chips
# 356024  openfoodfacts-contributors                              NaN
# 356025  openfoodfacts-contributors                              NaN
# 356026             usda-ndb-import                              NaN
#
# [356027 rows x 2 columns]

# %%
food.loc[2:6,"creator":"generic_name"]
# Out:
#            creator   created_t      created_datetime last_modified_t  \
# 2  usda-ndb-import  1489069957  2017-03-09T14:32:37Z      1489069957
# 3  usda-ndb-import  1489055731  2017-03-09T10:35:31Z      1489055731
# 4  usda-ndb-import  1489055653  2017-03-09T10:34:13Z      1489055653
# 5  usda-ndb-import  1489055651  2017-03-09T10:34:11Z      1489055651
# 6  usda-ndb-import  1489055730  2017-03-09T10:35:30Z      1489055730
#
#   last_modified_datetime                       product_name generic_name
# 2   2017-03-09T14:32:37Z                            Peanuts          NaN
# 3   2017-03-09T10:35:31Z             Organic Salted Nut Mix          NaN
# 4   2017-03-09T10:34:13Z                    Organic Polenta          NaN
# 5   2017-03-09T10:34:11Z  Breadshop Honey Gone Nuts Granola          NaN
# 6   2017-03-09T10:35:30Z      Organic Long Grain White Rice          NaN

# %% [markdown]
# # Step 11. What is the product name of the 19th observation?

# %%
food.loc[19,"product_name"]
# Out:
# 'Organic Oat Groats'

# %%
for i in range(len(food)):
    a=food.iloc[i]
    if i==19:
        print(a["product_name"])
# Out:
# Organic Oat Groats
